# %% [markdown]
# <a href="https://colab.research.google.com/github/hyuzenn/Selection-of-Location-of-Public-Housing-/blob/main/Selection_of_Location_of_Public_Housing_for_Stabilization_of_Housing_for_Single_person_Households_in_Seoul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##워드 클라우드

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
f = open('/content/drive/MyDrive/AI/프로젝트파일/공공 임대주택 긍정.txt')

text = f.read()
print(text)
# Out:
# 긍정
# 정선 곳곳 공공임대주택 건립 "주거복지 실현"
# 내포신도시 공공임대아파트 6년 살면 분양가 매입
# 경기도, 공공임대주택 3곳 '커뮤니티 활성화 사업' 추진
# 'LH 마크 뗀 임대주택' 선도단지 준공
# “LH 독점 깬다”…‘공공주택사업’ 민간에 전격 개방
# "평창군, ‘정주여건 조성’ 공공임대주택 건립 확대 박차!
# 공공지원 민간임대 ‘힐스테이트 동탄포레’ 15일 견본주택 개관
# '불가침 성역' LH 공공주택, '민간 경쟁' 개방한다
# 정부, 4년간 청년주택 58만호 공급…내년 공공분양 6.5만호·공공임대 5만호
# 평창군, 2027년까지 공공임대주택 500세대 확대
# LH '독점' 공공주택 삼성물산도 짓는다...LH 차장급도 재취업 심사
# 강릉 입암지구 등 강원 3곳 공공 임대주택 후보지로 선정
# “부동산 혹한기에 특수 청약 노려라”…공공지원민간임대 ‘이랜드 피어 대명’ 한정 공급
# 과천 통합공공임대 새달 입주…‘LH’ 마크 지워 차별도 지운다
# iH(인천도시공사), 송도 웰카운티 3단지 2세대 공급… 공공임대 분양 전환
# 울산연구원 "소규모 맞춤형 모듈러 공공주택 도입을"
# 광명 제16R구역 재개발 공공매입 임대주택’ 예비입주자 14가구 모집
# 유주택자 기회 넓힌 공공지원 민간임대주택...대형 건설사, 12월 임차인 모집 예고
# 민간, 공공주택사업 독자적 참여…지자체가 '감리업체' 선정
# 현대건설, 공공지원 민간임대 '힐스테이트 동탄포레' 12월 공급
# 부산 에코델타 공공분양주택 '전기안심 1등급 예비인증' 획득
# 목포시, 도시재생 공공주택 66호 공급…철거 이주민 등 입주
# LH, 통합공공임대주택 시범단지 605가구 준공
# 공공주택사업 민간개방 추진…'LH 독점' 깬다
# 삼척 도계리, ‘통합공공임대주택 후보지’로 최종 선정!
# 경남 의령군 '작은학교 살리기' 임대주택, 예비 입주자 추가 모집
# 제주개발공사, 통합공공임대주택 130세대 입주자 선정
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
from wordcloud import STOPWORDS

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
from PIL import Image
import numpy as np

# %%
path = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
mask1 = np.array(Image.open('/content/drive/MyDrive/AI/프로젝트파일/KakaoTalk_20231218_225501766_02.png'))
불용어 = STOPWORDS.union({'내년', '1인가구', '빛나는', '10명 중', '울주군', '중', '이하', '나',
                       '씩', '최대', '것으로', '그와', '등을', '에', '대전', '또', '등', '도', '듯'
                       '거의', '논란', '공공임대주택', '4만', '임대주택', '주택', '나서', '1인'
                       '혼자', '전세사기'})
wc = WordCloud(width=1500, height=1000,
                stopwords = 불용어,
               background_color = 'white',
               mask = mask1,
               font_path = path).generate(text)
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# ##판다스

# %% [markdown]
# ###데이터 업로드

# %%
import pandas as pd

# %%
매매가 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/서울시 구별 평당 매매가.xlsx')

# %%
CCTV = pd.read_csv('/content/drive/MyDrive/AI/프로젝트파일/CCTV.csv', encoding = "cp949", thousands=',')

# %%
문화공간 =  pd.read_csv('/content/drive/MyDrive/AI/프로젝트파일/서울시 문화공간 통계.csv')

# %%
응급실 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/구별 응급실 수.xlsx')

# %%
공원 =  pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/서울 동별 공원 real real.xlsx')

# %%
경찰소방서 =  pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/시내주요기관(경찰·소방관서)_20231219112517 (1).xlsx')

# %%
의료기관 =  pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/의료기관(구별)(2010년+이후)_20231219113027.xlsx')

# %%
주차장 =  pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/주차장.xlsx')

# %%
대학교 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/서울 대학교(동별) - 2.xlsx')

# %%
지하철 = pd.read_csv('/content/drive/MyDrive/AI/프로젝트파일/서울교통공사_자치구별지하철역정보_역개수.csv', encoding = "cp949")

# %%
버스 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/버스노선 합계 요약.xlsx')

# %%
경제점수 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/경제 가중치점수.xlsx')

# %%
교통점수 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/교통 가중치점수.xlsx')

# %%
안전점수 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/안전 가중치점수.xlsx')

# %%
인프라점수 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/인프라 가중치점수.xlsx')

# %%
의료점수 = pd.read_excel('/content/drive/MyDrive/AI/프로젝트파일/의료 가중치점수.xlsx')

# %% [markdown]
# ###의료

# %%
의료기관.drop(columns=['자치구별(1)'], axis=1, inplace= True)

# %%
의료기관.drop(columns=['2022.1', '2022.2', '2022.3', '2022.4', '2022.5', '2022.6', '2022.7', '2022.8','2022.9', '2022.10', '2022.11', '2022.12', '2022.13',
                   '2022.14', '2022.15', '2022.16', '2022.17', '2022.18', '2022.19', '2022.20', '2022.21', '2022.22', '2022.23', '2022.24', '2022.25',
    '2022.26', '2022.27'], inplace= True)

# %%
의료기관.rename(columns = {'자치구별(2)' : '자치구별'}, inplace = True)

# %%
의료기관.drop(index = [0, 1, 2, 3], axis = 0, inplace = True)

# %%
의료기관.reset_index(drop = True, inplace = True)

# %%
의료기관.rename(columns = {'2022' : '병원수'}, inplace = True)

# %%
의료기관
# Out:
#     자치구별   병원수
# 0    종로구   480
# 1     중구   579
# 2    용산구   327
# 3    성동구   466
# 4    광진구   564
# 5   동대문구   597
# 6    중랑구   547
# 7    성북구   541
# 8    강북구   466
# 9    도봉구   375
# 10   노원구   752
# 11   은평구   702
# 12  서대문구   440
# 13   마포구   768
# 14   양천구   663
# 15   강서구   921
# 16   구로구   601
# 17   금천구   358
# 18  영등포구   797
# 19   동작구   595
# 20   관악구   714
# 21   서초구  1371
# 22   강남구  2815
# 23   송파구  1250
# 24   강동구   867

# %%
응급실.rename(columns = {'소계' : '자치구별'}, inplace = True)

# %%
응급실.drop(columns = ['병원수', '합계', '백분율'], inplace = True)

# %%
응급실.rename(columns = {'응급실 수' : '응급실수'}, inplace = True)

# %%
응급실
# Out:
#     자치구별  응급실수
# 0    종로구     4
# 1     중구     1
# 2    용산구     2
# 3    성동구     4
# 4    광진구     3
# 5   동대문구     9
# 6    중랑구     1
# 7    성북구     3
# 8    강북구     4
# 9    도봉구     3
# 10   노원구     3
# 11   은평구     2
# 12  서대문구     4
# 13   마포구     2
# 14   양천구     2
# 15   강서구     2
# 16   구로구     3
# 17   금천구     1
# 18  영등포구     4
# 19   동작구     3
# 20   관악구     2
# 21   서초구     2
# 22   강남구     1
# 23   송파구     1
# 24   강동구     1

# %%
의료 = pd.merge(의료기관, 응급실, on = '자치구별')

# %%
의료['합계'] = 의료['병원수'] + 의료['응급실수']

# %%
의료.sort_values('합계', ascending = False, inplace = True)

# %%
의료.reset_index(drop = True, inplace = True)

# %%
의료
# Out:
#     자치구별   병원수  응급실수    합계
# 0    강남구  2815     1  2816
# 1    서초구  1371     2  1373
# 2    송파구  1250     1  1251
# 3    강서구   921     2   923
# 4    강동구   867     1   868
# 5   영등포구   797     4   801
# 6    마포구   768     2   770
# 7    노원구   752     3   755
# 8    관악구   714     2   716
# 9    은평구   702     2   704
# 10   양천구   663     2   665
# 11  동대문구   597     9   606
# 12   구로구   601     3   604
# 13   동작구   595     3   598
# 14    중구   579     1   580
# 15   광진구   564     3   567
# 16   중랑구   547     1   548
# 17   성북구   541     3   544
# 18   종로구   480     4   484
# 19   강북구   466     4   470
# 20   성동구   466     4   470
# 21  서대문구   440     4   444
# 22   도봉구   375     3   378
# 23   금천구   358     1   359
# 24   용산구   327     2   329

# %% [markdown]
# ###안전

# %%
CCTV.drop(index = [0], axis = 0, inplace = True)

# %%
CCTV.drop(columns=['Unnamed: 0'], axis = 1, inplace = True)

# %%
CCTV.rename(columns = {'구분' : '자치구별'}, inplace = True)

# %%
CCTV
# Out:
#     자치구별    총계
# 1    종로구  1966
# 2    중 구  2584
# 3    용산구  2970
# 4    성동구  4175
# 5    광진구  3592
# 6   동대문구  2759
# 7    중랑구  4193
# 8    성북구  4957
# 9    강북구  3321
# 10   도봉구  2385
# 11   노원구  2626
# 12   은평구  4653
# 13  서대문구  3538
# 14   마포구  2638
# 15   양천구  3890
# 16   강서구  3353
# 17   구로구  4831
# 18   금천구  2885
# 19  영등포구  4660
# 20   동작구  2690
# 21   관악구  5642
# 22   서초구  4995
# 23   강남구  7243
# 24   송파구  3253
# 25   강동구  3192

# %%
경찰소방서.drop(columns=['자치구별(1)'], axis = 1, inplace = True)

# %%
경찰소방서.drop(index = [1], axis = 0, inplace = True)

# %%
경찰소방서.drop(index = [27], axis = 0, inplace = True)

# %%
경찰소방서.drop(index = [0], axis = 0, inplace = True)

# %%
경찰소방서.reset_index(drop = True, inplace = True)

# %%
경찰소방서.rename(columns = {'2022' : '경찰청', '2022.1' : '경찰서', '2022.2' : '지구대파출소치안센터', '2022.3' : '소방본부', '2022.4' : '소방서', '2022.5' : '119안전센터'}, inplace = True)

# %%
경찰소방서.rename(columns = {'자치구별(2)' : '자치구별'}, inplace = True)

# %%
경찰소방서['합계'] = 경찰소방서['경찰청'] + 경찰소방서['경찰서'] + 경찰소방서['지구대파출소치안센터'] + 경찰소방서['소방본부'] + 경찰소방서['소방서'] + 경찰소방서['119안전센터']

# %%
경찰소방서.drop(columns=['Unnamed: 8'], axis = 1, inplace = True)

# %%
경찰소방서_합계 = 경찰소방서[['자치구별', '합계']]

# %%
경찰소방서
# Out:
#     자치구별 경찰청 경찰서 지구대파출소치안센터 소방본부 소방서 119안전센터  합계
# 0    종로구   1   2         22    0   1       6  32
# 1     중구   0   2         18    1   1       5  27
# 2    용산구   0   1         12    0   1       5  19
# 3    성동구   0   1         15    0   1       4  21
# 4    광진구   0   1         12    0   1       3  17
# 5   동대문구   0   1         20    0   1       5  27
# 6    중랑구   0   1         17    0   1       4  23
# 7    성북구   0   2         24    0   1       4  31
# 8    강북구   0   1         14    0   1       4  20
# 9    도봉구   0   1          9    0   1       4  15
# 10   노원구   0   1         16    0   1       5  23
# 11   은평구   0   2         20    0   1       4  27
# 12  서대문구   1   1         10    0   1       4  17
# 13   마포구   0   1         15    0   1       6  23
# 14   양천구   0   1         15    0   1       5  22
# 15   강서구   0   1         12    0   1       6  20
# 16   구로구   0   1         17    0   1       6  25
# 17   금천구   0   1         12    0   1       2  16
# ...

# %%
안전 = pd.merge(경찰소방서_합계, CCTV, on = '자치구별')

# %%
안전.rename(columns = {'합계' : '경찰소방서 합계', '총계' : 'CCTV 합계'}, inplace = True)

# %%
안전['합계'] = 안전['경찰소방서 합계'] + 안전['CCTV 합계']

# %%
안전.sort_values('합계', ascending = False, inplace = True)

# %%
안전.reset_index(drop = True, inplace = True)

# %%
안전
# Out:
#     자치구별 경찰소방서 합계  CCTV 합계    합계
# 0    강남구       30     7243  7273
# 1    관악구       24     5642  5666
# 2    서초구       28     4995  5023
# 3    성북구       31     4957  4988
# 4    구로구       25     4831  4856
# 5   영등포구       22     4660  4682
# 6    은평구       27     4653  4680
# 7    중랑구       23     4193  4216
# 8    성동구       21     4175  4196
# 9    양천구       22     3890  3912
# 10   광진구       17     3592  3609
# 11  서대문구       17     3538  3555
# 12   강서구       20     3353  3373
# 13   강북구       20     3321  3341
# 14   송파구       29     3253  3282
# 15   강동구       24     3192  3216
# 16   용산구       19     2970  2989
# 17   금천구       16     2885  2901
# 18  동대문구       27     2759  2786
# 19   동작구       23     2690  2713
# 20   마포구       23     2638  2661
# 21   노원구       23     2626  2649
# 22   도봉구       15     2385  2400
# 23   종로구       32     1966  1998

# %% [markdown]
# ###인프라

# %%
문화공간.drop(index=[0, 1, 2], axis=0, inplace= True)

# %%
문화공간.drop(columns=['자치구별(1)', '2022.1', '2022.2', '2022.3', '2022.4', '2022.5'], axis = 1, inplace= True)

# %%
문화공간.rename(columns = {'자치구별(2)' : '자치구별', '2022' : '합계'}, inplace = True)

# %%
문화공간.reset_index(drop = True, inplace = True)

# %%
문화공간.rename(columns = {'자치구별' : '자치구'}, inplace = True)

# %%
문화공간
# Out:
#      자치구   합계
# 0    종로구  167
# 1     중구   29
# 2    용산구   14
# 3    성동구   10
# 4    광진구   14
# 5   동대문구    3
# 6    중랑구    1
# 7    성북구   13
# 8    강북구    6
# 9    도봉구    5
# 10   노원구    5
# 11   은평구    1
# 12  서대문구    9
# 13   마포구   38
# 14   양천구    5
# 15   강서구    4
# 16   구로구    7
# 17   금천구    5
# 18  영등포구    8
# 19   동작구    3
# 20   관악구    1
# 21   서초구   29
# 22   강남구   41
# 23   송파구   13
# 24   강동구    5

# %%
공원.rename(columns = {'Unnamed: 4' : '동별'}, inplace = True)

# %%
공원.drop(columns=['동별'], axis=1, inplace = True)

# %%
공원.drop(공원.index[25:500], axis=0, inplace = True)

# %%
공원
# Out:
#    동별(1) 동별(2)        동별(3)  공원 수   자치구    합계
# 0    서울시    소계           소계     0   종로구  12.0
# 1    서울시   종로구          사직동     3    중구   3.0
# 2    서울시   종로구          삼청동     1   용산구   2.0
# 3    서울시   종로구          부암동     1   성동구   7.0
# 4    서울시   종로구          평창동     0   광진구   1.0
# 5    서울시   종로구          무악동     0  동대문구   5.0
# 6    서울시   종로구          교남동     0   중랑구  20.0
# 7    서울시   종로구          가회동     0   성북구   4.0
# 8    서울시   종로구  종로1.2.3.4가동     1   강북구   7.0
# 9    서울시   종로구      종로5.6가동     0   도봉구  20.0
# 10   서울시   종로구          이화동     2   노원구  11.0
# 11   서울시   종로구          혜화동     1   은평구   9.0
# 12   서울시   종로구         창신1동     0  서대문구   6.0
# 13   서울시   종로구         창신2동     0   마포구   9.0
# 14   서울시   종로구         창신3동     0   양천구   7.0
# 15   서울시   종로구         숭인1동     1   강서구  14.0
# 16   서울시   종로구         숭인2동     1   구로구   5.0
# 17   서울시   종로구        청운효자동     1   금천구  14.0
# 18   서울시    중구          소공동     0  영등포구   6.0
# ...

# %%
주차장.drop(columns=['동별(1)', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'], axis = 1, inplace= True)

# %%
주차장.drop(index=[0, 1, 2, 3, 4], axis=0, inplace= True)

# %%
주차장.reset_index(drop = True, inplace = True)

# %%
주차장.rename(columns = {'동별(2)' : '자치구', 'Unnamed: 2' : '주차장 수'}, inplace = True)

# %%
주차장.rename(columns = {'자치구별' : '자치구', '주차장 수' : '합계'}, inplace = True)

# %%
주차장
# Out:
#      자치구     합계
# 0    종로구  14626
# 1     중구   8856
# 2    용산구  14494
# 3    성동구  13648
# 4    광진구  32032
# 5   동대문구  18592
# 6    중랑구  23380
# 7    성북구  26298
# 8    강북구  21566
# 9    도봉구  19478
# 10   노원구  12912
# 11   은평구  40618
# 12  서대문구  15726
# 13   마포구  27904
# 14   양천구  23734
# 15   강서구  37910
# 16   구로구  18592
# 17   금천구  17848
# 18  영등포구  21798
# 19   동작구  19220
# 20   관악구  38302
# 21   서초구  27314
# 22   강남구  42376
# 23   송파구  36244
# 24   강동구  26340

# %%
대학교.reset_index(drop=True, inplace=True)

# %%
대학교.drop(columns=['소계', '소계.1', '고등교육기관 수', 'Unnamed: 4'], axis = 1, inplace= True)

# %%
대학교.drop(대학교.index[25:500], axis=0, inplace= True)

# %%
대학교
# Out:
#     서울시   자치구    합계
# 0   NaN   종로구   7.0
# 1   NaN    중구   3.0
# 2   NaN   용산구   2.0
# 3   NaN   성동구   2.0
# 4   NaN   광진구   3.0
# 5   NaN  동대문구   7.0
# 6   NaN   중랑구   6.0
# 7   NaN   성북구  15.0
# 8   NaN   강북구   0.0
# 9   NaN   도봉구   4.0
# 10  NaN   노원구  19.0
# 11  NaN   은평구   2.0
# 12  NaN  서대문구  13.0
# 13  NaN   마포구   2.0
# 14  NaN   양천구   0.0
# 15  NaN   강서구  13.0
# 16  NaN   구로구   6.0
# 17  NaN   금천구   0.0
# 18  NaN  영등포구   1.0
# 19  NaN   동작구  12.0
# 20  NaN   관악구   1.0
# 21  NaN   서초구  16.0
# 22  NaN   강남구   0.0
# 23  NaN   송파구   2.0
# 24  NaN   강동구   0.0

# %%
인프라 = pd.merge(문화공간, 대학교, on='자치구')
인프라 = pd.merge(인프라, 공원, on='자치구', suffixes=('_문화공간대학교', '_공원'))
인프라 = pd.merge(인프라, 주차장, on='자치구', suffixes=('_공원', '_주차장'))
인프라 = pd.merge(인프라, 주차장, on='자치구')
인프라['합계'] = pd.to_numeric(문화공간['합계']) + pd.to_numeric(대학교['합계']) + pd.to_numeric(공원['합계']) + pd.to_numeric(주차장['합계'])
인프라[['자치구', '합계']]
# Out:
#      자치구       합계
# 0    종로구  14812.0
# 1     중구   8891.0
# 2    용산구  14512.0
# 3    성동구  13667.0
# 4    광진구  32050.0
# 5   동대문구  18607.0
# 6    중랑구  23407.0
# 7    성북구  26330.0
# 8    강북구  21579.0
# 9    도봉구  19507.0
# 10   노원구  12947.0
# 11   은평구  40630.0
# 12  서대문구  15754.0
# 13   마포구  27953.0
# 14   양천구  23746.0
# 15   강서구  37941.0
# 16   구로구  18610.0
# 17   금천구  17867.0
# 18  영등포구  21813.0
# 19   동작구  19249.0
# 20   관악구  38306.0
# 21   서초구  27362.0
# 22   강남구  42423.0
# 23   송파구  36278.0
# 24   강동구  26352.0

# %% [markdown]
# ###교통

# %%
버스
# Out:
#      자치구    합계
# 0    강남구  2582
# 1    강동구  1243
# 2    강북구   927
# 3    강서구  1927
# 4    관악구  1381
# 5    광진구   957
# 6    구로구  1311
# 7    금천구   894
# 8    노원구  1704
# 9    도봉구   923
# 10  동대문구  1445
# 11   동작구   987
# 12   마포구  1529
# 13  서대문구  1669
# 14   서초구  2545
# 15   성동구   685
# 16   성북구  1298
# 17   송파구  2481
# 18   양천구  1413
# 19  영등포구  1783
# 20   용산구   995
# 21   은평구  1869
# 22   종로구  1245
# 23    중구  1257
# 24   중랑구  1730

# %%
지하철
# Out:
#      자치구  역개수
# 0    강남구   21
# 1    강동구   14
# 2    강북구    3
# 3    강서구    9
# 4    관악구    4
# 5    광진구   11
# 6    구로구    7
# 7    금천구    1
# 8    노원구   13
# 9    도봉구    3
# 10  동대문구    6
# 11   동작구   12
# 12   마포구   16
# 13  서대문구    5
# 14   서초구   12
# 15   성동구   14
# 16   성북구    9
# 17   송파구   28
# 18   양천구    5
# 19  영등포구   11
# 20   용산구   10
# 21   은평구   13
# 22   종로구   15
# 23    중구   23
# 24   중랑구    8

# %%
교통 = pd.merge(버스, 지하철, on = '자치구')
교통['합계'] = 버스['합계'] + 지하철['역개수']
교통[['자치구', '합계']]
# Out:
#      자치구    합계
# 0    강남구  2603
# 1    강동구  1257
# 2    강북구   930
# 3    강서구  1936
# 4    관악구  1385
# 5    광진구   968
# 6    구로구  1318
# 7    금천구   895
# 8    노원구  1717
# 9    도봉구   926
# 10  동대문구  1451
# 11   동작구   999
# 12   마포구  1545
# 13  서대문구  1674
# 14   서초구  2557
# 15   성동구   699
# 16   성북구  1307
# 17   송파구  2509
# 18   양천구  1418
# 19  영등포구  1794
# 20   용산구  1005
# 21   은평구  1882
# 22   종로구  1260
# 23    중구  1280
# 24   중랑구  1738

# %% [markdown]
# ##시각화

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 15.6 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# '지역' 변수를 리스트로 변경
지역 = ['강남구', '서초구', '송파구', '강서구', '강동구', '영등포구', '마포구', '노원구', '관악구', '은평구', '양천구',
      '동대문구', '구로구', '동작구', '중구', '광진구', '중랑구', '성북구', '종로구', '강북구', '성동구', '서대문구', '도봉구', '금천구', '용산구']
의료통계 = [2816, 1373, 1251, 923, 868, 801, 770, 755, 716, 704, 665, 606, 604, 598, 580, 567, 548, 544, 484, 470, 470, 444, 378, 359, 329]
plt.figure(figsize=(18, 6))

# 리스트로 변환한 '지역' 변수 사용
plt.bar(지역, 의료통계, label='의료통계')

plt.xlabel('지역')
plt.ylabel('의료통계')

plt.title('서울시 각 구별 의료 통계')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# '지역' 변수를 리스트로 변경
지역 = ['서초구', '강남구', '용산구', '송파구', '성동구', '양천구', '광진구', '마포구', '강동구', '동작구', '영등포구', '종로구', '중구', '강서구', '서대문구', '동대문구', '노원구', '관악구', '성북구', '구로구', '은평구', '중랑구', '강북구', '금천구', '도봉구']
매매가 = [8021, 7783, 6519, 5749, 4991, 4884, 4867, 4653, 4293, 4218, 4214, 4089, 3975, 3683, 3515, 3313, 3191, 3132, 3096, 3033, 3010, 2826, 2672, 2669, 2655]

# 그래프 크기 조절
plt.figure(figsize=(18, 6))

# 리스트로 변환한 '지역' 변수 사용
plt.bar(지역, 매매가, label='매매가')

plt.xlabel('지역')
plt.ylabel('매매가')
plt.title('서울시 구별 평당 매매가')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

data = {
    '자치구별': ['강남구', '관악구', '서초구', '성북구', '구로구', '영등포구', '은평구', '중랑구', '성동구', '양천구',
             '광진구', '서대문구', '강서구', '강북구', '송파구', '강동구', '용산구', '금천구', '동대문구', '동작구',
             '마포구', '노원구', '도봉구', '종로구'],
    '합계': [7273, 5666, 5023, 4988, 4856, 4682, 4680, 4216, 4196, 3912, 3609, 3555, 3373, 3341, 3282, 3216, 2989, 2901, 2786, 2713, 2661, 2649, 2400, 1998]
}

df = pd.DataFrame(data)

# 자치구별과 합계 열만 선택
df_selected = df[['자치구별', '합계']]

# 그래프 그리기
plt.figure(figsize=(12, 6))
plt.bar(df_selected['자치구별'], df_selected['합계'], color='skyblue')
plt.title('자치구별 합계 그래프')
plt.xlabel('자치구별')
plt.ylabel('합계')
plt.xticks(rotation=45, ha='right')  # x축 레이블 회전
plt.show()

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# ##지도시각화

# %%
인프라_sorted = 인프라.sort_values(by='합계', ascending=False)
인프라_sorted[['자치구', '합계']]
# Out:
#      자치구       합계
# 22   강남구  42423.0
# 11   은평구  40630.0
# 20   관악구  38306.0
# 15   강서구  37941.0
# 23   송파구  36278.0
# 4    광진구  32050.0
# 13   마포구  27953.0
# 21   서초구  27362.0
# 24   강동구  26352.0
# 7    성북구  26330.0
# 14   양천구  23746.0
# 6    중랑구  23407.0
# 18  영등포구  21813.0
# 8    강북구  21579.0
# 9    도봉구  19507.0
# 19   동작구  19249.0
# 16   구로구  18610.0
# 5   동대문구  18607.0
# 17   금천구  17867.0
# 12  서대문구  15754.0
# 0    종로구  14812.0
# 2    용산구  14512.0
# 3    성동구  13667.0
# 10   노원구  12947.0
# 1     중구   8891.0

# %%
pip install folium

# %%
import folium
from branca.colormap import LinearColormap
districts = {
    '종로구': [37.572067, 126.979424],
    '중구': [37.563873, 126.997570],
    '용산구': [37.532768, 126.990021],
    '성동구': [37.563279, 127.036441],
    '광진구': [37.548964, 127.085637],
    '동대문구': [37.574460, 127.039187],
    '중랑구': [37.595379, 127.093967],
    '성북구': [37.589562, 127.016700],
    '강북구': [37.646995, 127.014716],
    '도봉구': [37.653358, 127.052682],
    '노원구': [37.654527, 127.083226],
    '은평구': [37.603481, 126.929173],
    '서대문구': [37.579428, 126.936771],
    '마포구': [37.563756, 126.908421],
    '양천구': [37.527061, 126.856153],
    '강서구': [37.565762, 126.822656],
    '구로구': [37.495632, 126.858433],
    '금천구': [37.460097, 126.900155],
    '영등포구': [37.525852, 126.901006],
    '동작구': [37.499487, 126.977661],
    '관악구': [37.478290, 126.951502],
    '서초구': [37.483574, 127.032248],
    '강남구': [37.517236, 127.047325],
    '송파구': [37.504853, 127.114482],
    '강동구': [37.549208, 127.146482],
}
data = {
    '종로구': 14812.0,
    '중구': 8891.0,
    '용산구': 14512.0,
    '성동구': 13667.0,
    '광진구': 32050.0,
    '동대문구': 18607.0,
    '중랑구': 23407.0,
    '성북구': 26330.0,
    '강북구': 26352.0,
    '도봉구': 21579.0,
    '노원구': 19507.0,
    '은평구': 12947.0,
    '서대문구': 40630.0,
    '마포구': 15754.0,
    '양천구': 27953.0,
    '강서구': 23746.0,
    '구로구': 37941.0,
    '금천구': 18610.0,
    '영등포구': 21813.0,
    '동작구': 19249.0,
    '관악구': 17867.0,
    '서초구': 27362.0,
    '강남구': 42423.0,
    '송파구': 36278.0,
    '강동구': 26352.0,
}
def get_color(value):
    if value is None:
        return '#gray'
    elif value >= 38000:
        return '#ff4500'
    elif value >= 30000:
        return '#ff6347'
    elif value >= 20000:
        return '#ff7f50'
    elif value >= 10000:
        return '#fa8072'
    else:
        return '#1e90ff'
seoul_map = folium.Map(location=[37.55, 127], zoom_start=11)
folium.Choropleth(
    geo_data='https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json',
    data=data,
    columns=['구별', '합계'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population by District',
).add_to(seoul_map)
seoul_map.save('seoul_map_colored.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
교통_sorted = 교통.sort_values(by='합계', ascending=False)
교통_sorted[['자치구', '합계']]
# Out:
#      자치구    합계
# 0    강남구  2603
# 14   서초구  2557
# 17   송파구  2509
# 3    강서구  1936
# 21   은평구  1882
# 19  영등포구  1794
# 24   중랑구  1738
# 8    노원구  1717
# 13  서대문구  1674
# 12   마포구  1545
# 10  동대문구  1451
# 18   양천구  1418
# 4    관악구  1385
# 6    구로구  1318
# 16   성북구  1307
# 23    중구  1280
# 22   종로구  1260
# 1    강동구  1257
# 20   용산구  1005
# 11   동작구   999
# 5    광진구   968
# 2    강북구   930
# 9    도봉구   926
# 7    금천구   895
# 15   성동구   699

# %%
import folium
import pandas as pd
from branca.colormap import LinearColormap

# 자치구 및 합계 데이터
data = {
    '자치구': ['강남구', '서초구', '송파구', '강서구', '은평구', '영등포구', '중랑구', '노원구', '서대문구', '마포구', '동대문구', '양천구', '관악구', '구로구', '성북구', '중구', '종로구', '강동구', '용산구', '동작구', '광진구', '강북구', '도봉구', '금천구', '성동구'],
    '합계': [2603, 2557, 2509, 1936, 1882, 1794, 1738, 1717, 1674, 1545, 1451, 1418, 1385, 1318, 1307, 1280, 1260, 1257, 1005, 999, 968, 930, 926, 895, 699]
}

df = pd.DataFrame(data)

# 색상 설정 함수
def get_color(value):
    if value is None:
        return '#gray'
    elif value >= 2500:
        return '#ff4500'
    elif value >= 2000:
        return '#ff6347'
    elif value >= 1500:
        return '#ff7f50'
    elif value >= 1000:
        return '#fa8072'
    else:
        return '#1e90ff'

seoul_map = folium.Map(location=[37.55, 127], zoom_start=11)
folium.Choropleth(
    geo_data='https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json',
    data=df,
    columns=['자치구', '합계'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population by District',
).add_to(seoul_map)

seoul_map.save('seoul_map_colored.html')
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 최종결론

# %%
최종 = pd.merge(경제점수, 교통점수,  on = '자치구')
최종 = pd.merge(최종, 안전점수,  on = '자치구')
최종 = pd.merge(최종, 인프라점수,  on = '자치구')
최종 = pd.merge(최종, 의료점수,  on = '자치구')
최종['점수'] = 경제점수['가중치점수'] + 교통점수['가중치점수'] + 안전점수['가중치점수'] + 인프라점수['가중치점수'] + 의료점수['가중치점수']
최종[['자치구', '점수']]
# Out:
# <ipython-input-15-52b4ae431b62>:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'점수_x', '가중치점수_x'} in the result is deprecated and will raise a MergeError in a future version.
#   최종 = pd.merge(최종, 인프라점수,  on = '자치구')
#      자치구       점수
# 0    종로구  0.38730
# 1     중구  0.41240
# 2    용산구  0.29560
# 3    성동구  0.28295
# 4    광진구  0.45605
# 5   동대문구  0.51800
# 6    중랑구  0.74775
# 7    성북구  0.68205
# 8    강북구  0.54695
# 9    도봉구  0.45560
# 10   노원구  0.45575
# 11   은평구  0.78870
# 12  서대문구  0.51430
# 13   마포구  0.41630
# 14   양천구  0.43545
# 15   강서구  0.61855
# 16   구로구  0.58215
# 17   금천구  0.42595
# 18  영등포구  0.54200
# 19   동작구  0.28315
# 20   관악구  0.65175
# 21   서초구  0.48940
# 22   강남구  0.62060
# 23   송파구  0.33300
# 24   강동구  0.33355

# %%
최종_sorted = 최종.sort_values(by='점수', ascending=False)
최종_sorted[['자치구', '점수']]
# Out:
#      자치구       점수
# 11   은평구  0.78870
# 6    중랑구  0.74775
# 7    성북구  0.68205
# 20   관악구  0.65175
# 22   강남구  0.62060
# 15   강서구  0.61855
# 16   구로구  0.58215
# 8    강북구  0.54695
# 18  영등포구  0.54200
# 5   동대문구  0.51800
# 12  서대문구  0.51430
# 21   서초구  0.48940
# 4    광진구  0.45605
# 10   노원구  0.45575
# 9    도봉구  0.45560
# 14   양천구  0.43545
# 17   금천구  0.42595
# 13   마포구  0.41630
# 1     중구  0.41240
# 0    종로구  0.38730
# 24   강동구  0.33355
# 23   송파구  0.33300
# 2    용산구  0.29560
# 19   동작구  0.28315
# 3    성동구  0.28295

# %%
import matplotlib.pyplot as plt

자치구 = ['은평구', '중랑구', '성북구', '관악구', '강남구', '강서구', '구로구', '강북구',
       '영등포구', '동대문구', '서대문구', '서초구', '광진구', '노원구', '도봉구', '양천구',
       '금천구', '마포구', '중구', '종로구', '강동구', '송파구', '용산구', '동작구', '성동구'
]
점수 = [0.78870, 0.74775, 0.68205, 0.65175, 0.62060, 0.61855, 0.58215, 0.54695, 0.54200,
      0.51800, 0.51430, 0.48940, 0.45605, 0.45575, 0.45560, 0.43545, 0.42595, 0.41630,
      0.41240, 0.38730, 0.33355, 0.33300, 0.29560, 0.28315, 0.28295]

plt.figure(figsize=(18, 6))

plt.bar(자치구, 점수, label='점수')

plt.xlabel('자치구')
plt.ylabel('점수')

plt.title('최종 구별 점수')
plt.legend()
plt.show()
